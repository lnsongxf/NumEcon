# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numecon
numecon.ged
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-2ec3eee84719> in <module>
#       1 import numecon
# ----> 2 numecon.ged
#
# AttributeError: module 'numecon' has no attribute 'ged'
