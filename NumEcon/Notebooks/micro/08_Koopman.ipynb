# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Model" data-toc-modified-id="Model-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Model</a></span></li><li><span><a href="#Static:-Walras-equilibrium-in-Koopdiagram" data-toc-modified-id="Static:-Walras-equilibrium-in-Koopdiagram-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Static: Walras equilibrium in Koopdiagram</a></span></li><li><span><a href="#Interactive:-Walras-equilibrium-in-Koopdiagram" data-toc-modified-id="Interactive:-Walras-equilibrium-in-Koopdiagram-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Interactive: Walras equilibrium in Koopdiagram</a></span></li></ul></div>

# %%
# setup
# %matplotlib inline
# %load_ext autoreload
# %autoreload 1

import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from mpl_toolkits.mplot3d.art3d import Poly3DCollection, Line3DCollection

import seaborn as sns
sns.set_style("whitegrid")
prop_cycle = plt.rcParams['axes.prop_cycle']
colors = prop_cycle.by_key()['color']

import ipywidgets as widgets

import numecon.micro.koopman as koopman
# %aimport numecon.micro.koopman

# %%
# %%html
# <style>
# .output_wrapper, .output {
#     height:auto !important;
#     max-height:5000px;  /* your desired max-height here */
# }
# .output_scroll {
#     box-shadow:none !important;
#     webkit-box-shadow:none !important;
# }
# </style>
# Out:
# <style>
# .output_wrapper, .output {
#     height:auto !important;
#     max-height:5000px;  /* your desired max-height here */
# }
# .output_scroll {
#     box-shadow:none !important;
#     webkit-box-shadow:none !important;
# }
# </style>

# %% [markdown]
# # Model

# %% [markdown]
# The **consumer** is described by:
#
# 1. A cobb-douglas utility function over leisure time ($f$) and consumption ($x$), $u(f,x)=f^{\alpha}x^{\beta}, \alpha,\beta >0$
# 2. A time endowment of $L>0$ and no endowment of the consumption good
#
# The **firm** is described by
#
# 1. A production function, $y = g(\ell) = A\ell^{\gamma}, \gamma \in (0,1)$, where $\ell$ is labor input and $y$ is output of the consumption good
# 2. Profit is given by $\Pi = p \cdot y - w \cdot \ell = p \cdot g(\ell) - w \cdot \ell$
#
#
# Both the **labor market** (wage $w$) and the **goods market** ($p$) is characterized by **perfect competition**.
#
# The **baseline parameters** are $\alpha = \beta = \gamma = A = 0.5$. The **numeraire** is $p=1$.

# %% [markdown]
# # Static: Walras equilibrium in Koopdiagram

# %%
# code

# a. consumer
consumer = {}
consumer['preferences'] = 'cobb_douglas'
consumer['alpha'] = 0.5
consumer['beta'] = 0.5

# b. firm
firm = {}
firm['gamma'] = 0.5
firm['A'] = 0.5

# c. model
w = 0.2
model = koopman.KoopmanModel(consumer,firm,w=w)
model.walras_figure()

# %% [markdown]
# # Interactive: Walras equilibrium in Koopdiagram

# %%
koopman.interactive_walras(alpha=0.5,beta=0.5,gamma=0.5,A=0.5,xmax=5)
# Out:
# interactive(children=(FloatSlider(value=0.5, description='$\\alpha$', max=5.0, min=0.01, step=0.01), FloatSlid…
